# %% [markdown]
# <a href="https://colab.research.google.com/github/ajayjosepaul/aiprojects/blob/main/SadTalker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title **setup（about 5 minutes）**
# !python --version
# !apt-get update
# !apt install software-properties-common
# !sudo dpkg --remove --force-remove-reinstreq python3-pip python3-setuptools python3-wheel
# !apt-get install python3-pip

print('Git clone project and install requirements...')
# !git clone https://github.com/cedro3/SadTalker.git &> /dev/null
# %cd /content/SadTalker
# !export PYTHONPATH=/content/SadTalker:$PYTHONPATH
# !python3 -m pip install torch torchvision torchaudio
# !apt update
# !apt install ffmpeg &> /dev/null
# !python3 -m pip install -r requirements_py312.txt
# Out:
# Python 3.12.12
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://cli.github.com/packages stable InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Hit:11 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Reading package lists... Done
# ...

# %%
# %cd /content/SadTalker
# !sed -i 's/numpy==1.23.5/numpy/' requirements_py312.txt
# !sed -i 's/scipy==1.10.1/scipy/' requirements_py312.txt
# !sed -i 's/torch==2.1.0/torch/' requirements_py312.txt
# !sed -i 's/torchvision==0.16.0/torchvision/' requirements_py312.txt
# !sed -i 's/torchaudio==2.1.0/torchaudio/' requirements_py312.txt
# !sed -i 's/#av==/av==/' requirements_py312.txt
# !sed -i 's/#audio==/audio==/' requirements_py312.txt
# !python3 -m pip install -r requirements_py312.txt
# !sed -i 's/av==/#av==/' requirements_py312.txt
# !sed -i 's/audio==/#audio==/' requirements_py312.txt
# Out:
# /content/SadTalker
# ERROR: Invalid requirement: '^audio==1.5.0': Expected package name at the start of dependency specifier
#     ^audio==1.5.0
#     ^ (from line 10 of requirements_py312.txt)

# %%
# %cd /content/SadTalker
# !sed -i 's/numpy==1.23.5/numpy/' requirements_py312.txt
# !sed -i 's/scipy==1.10.1/scipy/' requirements_py312.txt
# !sed -i 's/torch==2.1.0/torch/' requirements_py312.txt
# !sed -i 's/torchvision==0.16.0/torchvision/' requirements_py312.txt
# !sed -i 's/torchaudio==2.1.0/torchaudio/' requirements_py312.txt
# !sed -i 's/#av==/av==/' requirements_py312.txt
# !sed -i 's/#audio==/audio==/' requirements_py312.txt
# !python3 -m pip install -r requirements_py312.txt
# !sed -i 's/av==/#av==/' requirements_py312.txt
# !sed -i 's/audio==/#audio==/' requirements_py312.txt
# Out:
# /content/SadTalker
# ERROR: Invalid requirement: '^audio==1.5.0': Expected package name at the start of dependency specifier
#     ^audio==1.5.0
#     ^ (from line 10 of requirements_py312.txt)

# %%
# %cd /content/SadTalker
# !sed -i 's/numpy==1.23.5/numpy/' requirements_py312.txt
# !sed -i 's/scipy==1.10.1/scipy/' requirements_py312.txt
# !sed -i 's/torch==2.1.0/torch/' requirements_py312.txt
# !sed -i 's/torchvision==0.16.0/torchvision/' requirements_py312.txt
# !sed -i 's/torchaudio==2.1.0/torchaudio/' requirements_py312.txt
# !python3 -m pip install -r requirements_py312.txt --no-deps --ignore-installed --no-warn-script-location $(grep -v '^av==' requirements_py312.txt | xargs)
# Out:
# /content/SadTalker
# ...
#   Using cached numpy-2.3.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 6.2 MB/s eta 0:00:00
# ...
#   Using cached tqdm-4.65.0-py3-none-any.whl.metadata (56 kB)
# ...
#   Using cached PyYAML-6.0.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# ...
#   Using cached face_alignment-1.3.5-py2.py3-none-any.whl.metadata (6.6 kB)
# ...
#   Using cached resampy-0.4.2-py3-none-any.whl.metadata (2.8 kB)
# ...
#   Using cached audio-1.5.0.tar.gz (2.1 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached basicsr-1.4.2.tar.gz (172 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached facexlib-0.3.0-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached gfpgan-1.3.8-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached einops-0.6.1-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached transformers-4.33.2-py3-none-any.whl.metadata (119 kB)
# ...

# %%
# %cd /content/SadTalker
# !python3 -m pip install numpy
# Out:
# /content/SadTalker
# ...

# %%
# %cd /content/SadTalker
# !ls requirements_py312.txt
# Out:
# /content/SadTalker
# requirements_py312.txt

# %%
#@title **download model（about 1 minute)**
print('Download pre-trained models...')
# !rm -rf checkpoints
# !bash scripts/download_models.sh
# Out:
# Download pre-trained models...
# --2025-11-02 02:50:45--  https://github.com/OpenTalker/SadTalker/releases/download/v0.0.2-rc/mapping_00109-model.pth.tar
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
#@title **inference for face**
image ='full3.png' #@param {type:"string"}
audio ='eluosi.wav' #@param {type:"string"}
source_image = 'examples/source_image/' + image
driven_audio = 'examples/driven_audio/' + audio

# !python3 inference.py --driven_audio $driven_audio \
           --source_image $source_image \
           --result_dir ./results --enhancer gfpgan
# Out:
# Traceback (most recent call last):
#   File "/content/SadTalker/inference.py", line 8, in <module>
#     from src.utils.preprocess import CropAndExtract
#   File "/content/SadTalker/src/utils/preprocess.py", line 11, in <module>
#     from src.face3d.models import networks
#   File "/content/SadTalker/src/face3d/models/__init__.py", line 22, in <module>
#     from src.face3d.models.base_model import BaseModel
#   File "/content/SadTalker/src/face3d/models/base_model.py", line 9, in <module>
#     from . import networks
#   File "/content/SadTalker/src/face3d/models/networks.py", line 19, in <module>
#     from kornia.geometry import warp_affine
# ModuleNotFoundError: No module named 'kornia'

# %%
#@title **play movie**
import glob
from IPython.display import HTML
from base64 import b64encode
import os, sys

# get the last from results
mp4_name = sorted(glob.glob('./results/*.mp4'))[-1]

mp4 = open('{}'.format(mp4_name),'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

print('Display animation: {}'.format(mp4_name), file=sys.stderr)
display(HTML("""
  <video width=256 controls>
        <source src="%s" type="video/mp4">
  </video>
  """ % data_url))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-3350458974.py in <cell line: 0>()
#       6
#       7 # get the last from results
# ----> 8 mp4_name = sorted(glob.glob('./results/*.mp4'))[-1]
#       9
#      10 mp4 = open('{}'.format(mp4_name),'rb').read()
#
# IndexError: list index out of range

# %%
# %cd /content/SadTalker
# !python3 -m pip install kornia
# Out:
# /content/SadTalker
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 61.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 108.8 MB/s eta 0:00:00
# ...

# %%
# %cd /content/SadTalker
# !python3 -m pip install av==10.0.0
# Out:
# /content/SadTalker
# ...
#   Using cached av-10.0.0.tar.gz (2.4 MB)
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build wheel ... error
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
#@title **inference for portrait**
image ='full3.png' #@param {type:"string"}
audio ='eluosi.wav' #@param {type:"string"}
source_image = 'examples/source_image/' + image
driven_audio = 'examples/driven_audio/' + audio

# !python3 inference.py --driven_audio $driven_audio \
           --source_image $source_image \
           --result_dir ./results --still --preprocess full --enhancer gfpgan

# %%
#@title **play movie**
import glob
from IPython.display import HTML
from base64 import b64encode
import os, sys

# get the last from results
mp4_name = sorted(glob.glob('./results/*.mp4'))[-1]

mp4 = open('{}'.format(mp4_name),'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

print('Display animation: {}'.format(mp4_name), file=sys.stderr)
display(HTML("""
  <video width=256 controls>
        <source src="%s" type="video/mp4">
  </video>
  """ % data_url))
